# %%
import sympy as sp
sp.init_printing()

# %%
x1 = sp.symbols('x1')
x2 = sp.symbols('x2')

f = x1**2 - x2**2

# %%
sp.plotting.plot3d(f, (x1, -2, 2), (x2, -2, 2))

# %%
sp.plotting.plot_contour(f, (x1, -2, 2), (x2, -2, 2))
